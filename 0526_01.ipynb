# %% [markdown]
# # Crawling 크롤링
#
# - 웹상의 데이터를 수집하기 위해서 크롤링을 사용
# - 웹페잊 접속(요청) -> (응답) -> 해당 웹 페이지에 어디에 위치 -> 값을 가져옴 -> 어떤 형식인지 -> 데이터 변환 -> 데이터 저장
# - Python : Numpy, Pandas, Requests, BeautifulSoup...
# - 데이터 수집

# %% [markdown]
# ## 요청 라이브러리 : Requests
#
# - !pip install requests
# - Http요청을 보내는데 사용하는 라이브러리
# - 클라이언트의 요청

# %%
print(requests.__version__)
# Out:
# 2.27.1

# %%
html = requests.get("http://www.paullab.co.kr/stock.html")

# %%
html
# Out:
# <Response [200]>

# %%
html.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n\n<head>\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta http-equiv="X-UA-Compatible" content="ie=edge">\n  <title>Document</title>\n  <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css">\n  <link rel="stylesheet" type="text/css" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" crossorigin="anonymous">\n  <style>\n    h1{\n      margin: 2rem;\n    }\n    h1>span{\n      font-size: 1rem;\n    }\n    .main {\n      width: 80%;\n      margin: 0 auto;\n      text-align: center;\n    }\n\n    table {\n      width: 100%;\n    }\n\n    a {\n      color: inherit;\n      cursor: pointer;\n      text-decoration: none;\n    }\n\n    a:hover {\n      color: #000;\n      text-decoration: none;\n    }\n\n    em {\n      font: inherit;\n    }\n\n    #infor
# ...

# %%
'''
# Post 요청 보내는 방법

import json

body = {'id' : 'aaa', 'pw' : 1234}
post = requests.post('url', data = json.dumps(body)))
'''
# Out:
# "\n# Post 요청 보내는 방법\n\nimport json\n\nbody = {'id' : 'aaa', 'pw' : 1234}\npost = requests.post('url', data = json.dumps(body)))\n"

# %% [markdown]
# ## BeautifulSoup

# %%
from bs4 import BeautifulSoup

html = requests.get('http://www.paullab.co.kr/stock.html')
text = html.text

# %%
html = requests.get('http://www.paullab.co.kr/stock.html')
text = html.text
soup = BeautifulSoup(text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <title>Document</title>
# <link href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet" type="text/css"/>
# <style>
#     h1{
#       margin: 2rem;
#     }
#     h1>span{
#       font-size: 1rem;
#     }
#     .main {
#       width: 80%;
#       margin: 0 auto;
#       text-align: center;
#     }
#
#     table {
#       width: 100%;
#     }
#
#     a {
#       color: inherit;
#       cursor: pointer;
#       text-decoration: none;
#     }
#
#     a:hover {
#       color: #000;
#       text-decoration: none;
#     }
#
#     em {
# ...

# %%
soup.title
# Out:
# <title>Document</title>

# %%
soup.title.string
# Out:
# 'Document'

# %%
soup.table
# Out:
# <table class="border-style" summary="시가총액 정보">
# <tr>
# <th class="strong" scope="row">시가총액</th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td class="strong"><em id="_market_sum">349조 2,323</em>억원</td>
# </tr>
# <tr>
# <th scope="row">
# <a class="link_site" href="#">시가총액순위<i class="fas fa-caret-right"></i></a>
# </th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td>위니브월드 <em id="_market_sum">1</em>위</td>
# </tr>
# <tr>
# <th scope="row">상장주식수</th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td><em id="_market_sum">5,969,782,550</em></td>
# </tr>
# </table>

# %%
soup.tr
# Out:
# <tr>
# <th class="strong" scope="row">시가총액</th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td class="strong"><em id="_market_sum">349조 2,323</em>억원</td>
# </tr>

# %%
soup.find('table')
# Out:
# <table class="border-style" summary="시가총액 정보">
# <tr>
# <th class="strong" scope="row">시가총액</th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td class="strong"><em id="_market_sum">349조 2,323</em>억원</td>
# </tr>
# <tr>
# <th scope="row">
# <a class="link_site" href="#">시가총액순위<i class="fas fa-caret-right"></i></a>
# </th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td>위니브월드 <em id="_market_sum">1</em>위</td>
# </tr>
# <tr>
# <th scope="row">상장주식수</th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td><em id="_market_sum">5,969,782,550</em></td>
# </tr>
# </table>

# %%
soup.find_all('table')
# Out:
# [<table class="border-style" summary="시가총액 정보">
#  <tr>
#  <th class="strong" scope="row">시가총액</th>
#  <!-- 공백은 의도적으로 넣은 것입니다. -->
#  <td class="strong"><em id="_market_sum">349조 2,323</em>억원</td>
#  </tr>
#  <tr>
#  <th scope="row">
#  <a class="link_site" href="#">시가총액순위<i class="fas fa-caret-right"></i></a>
#  </th>
#  <!-- 공백은 의도적으로 넣은 것입니다. -->
#  <td>위니브월드 <em id="_market_sum">1</em>위</td>
#  </tr>
#  <tr>
#  <th scope="row">상장주식수</th>
#  <!-- 공백은 의도적으로 넣은 것입니다. -->
#  <td><em id="_market_sum">5,969,782,550</em></td>
#  </tr>
#  </table>,
#  <table class="border-style" summary="업종상세 정보">
#  <tr>
#  <th class="strong" scope="row">현재가</th>
#  <td class="strong"><em id="_market_sum">349조 2,323</em>억원</td>
#  </tr>
#  <tr>
#  <th scope="row">52주 최고 <span class="bar">l</span> 최저</th>
#  <td>
#  <em>62,800</em>
#  <span class="bar">l</span>
#  <em>42,300</em>
#  </td>
#  </tr>
#  <tr>
#  <th scope="row">배당수익률 <span class="bar">l</span><span> 2019.12</span>
# ...

# %%
soup.find(id=('update'))
# Out:
# <span id="update">update : 20.12.30 / 해외 크롤링이 Block되어 있으므로 크롤링이 안되시는 분은 이 URL(http://paullab.synology.me/stock.html)을 사용하세요.</span>

# %%
soup.find_all('table', class_='table') # 결과값 -> 리스트
# Out:
# [<table class="table table-hover">
#  <tbody>
#  <tr>
#  <th scope="col">날짜</th>
#  <th scope="col">종가</th>
#  <th scope="col">전일비</th>
#  <th scope="col">시가</th>
#  <th scope="col">고가</th>
#  <th scope="col">저가</th>
#  <th scope="col">거래량</th>
#  </tr>
#  <tr>
#  <td align="center "><span class="date">2019.10.23</span></td>
#  <td class="num"><span>6,650</span></td>
#  <td class="num">
#  <img alt="상승 " height="6 " src="ico_up.gif " style="margin-right:4px; " width="7 "/><span>
#                              20
#                          </span>
#  </td>
#  <td class="num"><span>6,590</span></td>
#  <td class="num"><span>6,830</span></td>
#  <td class="num"><span>6,580</span></td>
#  <td class="num"><span>398,421</span></td>
#  </tr>
#  <tr>
#  <td align="center"><span class="date">2019.10.22</span></td>
#  <td class="num"><span>6,630</span></td>
#  <td class="num">
#  <img alt="하락" height="6" src="ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# ...

# %%
soup.find_all('table', class_='table')[0] # 결과값 -> 리스트
# Out:
# <table class="table table-hover">
# <tbody>
# <tr>
# <th scope="col">날짜</th>
# <th scope="col">종가</th>
# <th scope="col">전일비</th>
# <th scope="col">시가</th>
# <th scope="col">고가</th>
# <th scope="col">저가</th>
# <th scope="col">거래량</th>
# </tr>
# <tr>
# <td align="center "><span class="date">2019.10.23</span></td>
# <td class="num"><span>6,650</span></td>
# <td class="num">
# <img alt="상승 " height="6 " src="ico_up.gif " style="margin-right:4px; " width="7 "/><span>
#                             20
#                         </span>
# </td>
# <td class="num"><span>6,590</span></td>
# <td class="num"><span>6,830</span></td>
# <td class="num"><span>6,580</span></td>
# <td class="num"><span>398,421</span></td>
# </tr>
# <tr>
# <td align="center"><span class="date">2019.10.22</span></td>
# <td class="num"><span>6,630</span></td>
# <td class="num">
# <img alt="하락" height="6" src="ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
#                             190
# ...

# %%
tag = soup.find(id=('update'))

# %%
dir(tag)
# Out:
# ['DEFAULT_INTERESTING_STRING_TYPES',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_namespaces',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
# ...

# %%
tag.name
# Out:
# 'span'

# %%
tag['id']
# Out:
# 'update'

# %%
tag
# Out:
# bs4.BeautifulSoup

# %%
soup.select('#update')  # #을 이용해서 id값 찾기 / select 는 여러개의 값을 찾아옴
# Out:
# [<span id="update">update : 20.12.30 / 해외 크롤링이 Block되어 있으므로 크롤링이 안되시는 분은 이 URL(http://paullab.synology.me/stock.html)을 사용하세요.</span>]

# %%
soup.select('.table') # class가  table값을 찾아옴
# Out:
# [<table class="table table-hover">
#  <tbody>
#  <tr>
#  <th scope="col">날짜</th>
#  <th scope="col">종가</th>
#  <th scope="col">전일비</th>
#  <th scope="col">시가</th>
#  <th scope="col">고가</th>
#  <th scope="col">저가</th>
#  <th scope="col">거래량</th>
#  </tr>
#  <tr>
#  <td align="center "><span class="date">2019.10.23</span></td>
#  <td class="num"><span>6,650</span></td>
#  <td class="num">
#  <img alt="상승 " height="6 " src="ico_up.gif " style="margin-right:4px; " width="7 "/><span>
#                              20
#                          </span>
#  </td>
#  <td class="num"><span>6,590</span></td>
#  <td class="num"><span>6,830</span></td>
#  <td class="num"><span>6,580</span></td>
#  <td class="num"><span>398,421</span></td>
#  </tr>
#  <tr>
#  <td align="center"><span class="date">2019.10.22</span></td>
#  <td class="num"><span>6,630</span></td>
#  <td class="num">
#  <img alt="하락" height="6" src="ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# ...

# %%
soup.select('.table > tbody > tr > .num')
# Out:
# [<td class="num"><span>6,650</span></td>,
#  <td class="num">
#  <img alt="상승 " height="6 " src="ico_up.gif " style="margin-right:4px; " width="7 "/><span>
#                              20
#                          </span>
#  </td>,
#  <td class="num"><span>6,590</span></td>,
#  <td class="num"><span>6,830</span></td>,
#  <td class="num"><span>6,580</span></td>,
#  <td class="num"><span>398,421</span></td>,
#  <td class="num"><span>6,630</span></td>,
#  <td class="num">
#  <img alt="하락" height="6" src="ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
#                              190
#                          </span>
#  </td>,
#  <td class="num"><span>6,830</span></td>,
#  <td class="num"><span>6,930</span></td>,
#  <td class="num"><span>6,530</span></td>,
#  <td class="num"><span>919,571</span></td>,
#  <td class="num"><span>6,820</span></td>,
#  <td class="num">
# ...

# %%
soup.select('.table > tr') # tbody를 건너뛰고 바로 tr로 접근 불가능
# Out:
# []

# %%
# 여러 번 접근하기

one = soup.select('.main')[2]

# div > h2, h3, table # #information > div > div.tables
    # 크롬 브라우저 -> 오른쪽 클릭 -> 검사 -> (왼쪽 상단) 마우스 클릭 모양 선택 -> 내가 원하는 곳을 찾는다.
    # -> 오른쪽 클릭 -> copy -> copy select -> 자동으로 경로 복사
    # body > div:nth-child(5) > table

# %%
one  # div> h2, h3, table
# Out:
# <div class="main">
# <h2 id="제주코딩베이스캠프연구원">제주코딩베이스캠프 연구원</h2>
# <h3><span style="color: salmon">일별</span> 시세</h3>
# <table class="table table-hover">
# <tbody>
# <tr>
# <th scope="col">날짜</th>
# <th scope="col">종가</th>
# <th scope="col">전일비</th>
# <th scope="col">시가</th>
# <th scope="col">고가</th>
# <th scope="col">저가</th>
# <th scope="col">거래량</th>
# </tr>
# <tr>
# <td align="center "><span class="date">2019.10.23</span></td>
# <td class="num"><span>6,650</span></td>
# <td class="num">
# <img alt="상승 " height="6 " src="ico_up.gif " style="margin-right:4px; " width="7 "/><span>
#                             20
#                         </span>
# </td>
# <td class="num"><span>6,590</span></td>
# <td class="num"><span>6,830</span></td>
# <td class="num"><span>6,580</span></td>
# <td class="num"><span>398,421</span></td>
# </tr>
# <tr>
# <td align="center"><span class="date">2019.10.22</span></td>
# <td class="num"><span>6,630</span></td>
# <td class="num">
# ...

# %%
two = one.select('tbody > tr')

# %%
two
# Out:
# [<tr>
#  <th scope="col">날짜</th>
#  <th scope="col">종가</th>
#  <th scope="col">전일비</th>
#  <th scope="col">시가</th>
#  <th scope="col">고가</th>
#  <th scope="col">저가</th>
#  <th scope="col">거래량</th>
#  </tr>,
#  <tr>
#  <td align="center "><span class="date">2019.10.23</span></td>
#  <td class="num"><span>6,650</span></td>
#  <td class="num">
#  <img alt="상승 " height="6 " src="ico_up.gif " style="margin-right:4px; " width="7 "/><span>
#                              20
#                          </span>
#  </td>
#  <td class="num"><span>6,590</span></td>
#  <td class="num"><span>6,830</span></td>
#  <td class="num"><span>6,580</span></td>
#  <td class="num"><span>398,421</span></td>
#  </tr>,
#  <tr>
#  <td align="center"><span class="date">2019.10.22</span></td>
#  <td class="num"><span>6,630</span></td>
#  <td class="num">
#  <img alt="하락" height="6" src="ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
#                              190
# ...

# %%
two = one.select('div> h2, h3, table') # 동일한 위치에 각기 다른 태그를 조회하는 법
# Out:
# [<h2 id="제주코딩베이스캠프연구원">제주코딩베이스캠프 연구원</h2>,
#  <h3><span style="color: salmon">일별</span> 시세</h3>,
#  <table class="table table-hover">
#  <tbody>
#  <tr>
#  <th scope="col">날짜</th>
#  <th scope="col">종가</th>
#  <th scope="col">전일비</th>
#  <th scope="col">시가</th>
#  <th scope="col">고가</th>
#  <th scope="col">저가</th>
#  <th scope="col">거래량</th>
#  </tr>
#  <tr>
#  <td align="center "><span class="date">2019.10.23</span></td>
#  <td class="num"><span>6,650</span></td>
#  <td class="num">
#  <img alt="상승 " height="6 " src="ico_up.gif " style="margin-right:4px; " width="7 "/><span>
#                              20
#                          </span>
#  </td>
#  <td class="num"><span>6,590</span></td>
#  <td class="num"><span>6,830</span></td>
#  <td class="num"><span>6,580</span></td>
#  <td class="num"><span>398,421</span></td>
#  </tr>
#  <tr>
#  <td align="center"><span class="date">2019.10.22</span></td>
#  <td class="num"><span>6,630</span></td>
#  <td class="num">
# ...

# %% [markdown]
# - Requests -> BeutifulSoup -> 변환, 접근

# %% [markdown]
# ## FinanceDataReader
#
# - 주식 가격, 지수, 환율, 암화 화폐 가격 ...
# - 시계열 데이터 수집
# - 거래소별, 종목(코드)별, 단축(코드)별 데이터 수집 가능

# %% [markdown]
# ### 라이브러리 설치

# %%
# !pip install finance-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## 라이브러리 사용

# %%
import FinanceDataReader as fdr

# %%
fdr.__version__ # 버전 확인 / 설치 여부 확인
# Out:
# '0.9.50'

# %% [markdown]
# ### krx 한국 거래소의 주식 리스트

# %%
# fdr 이용해서 데이터를 불러오면 -> 데이터프레임 형태

df_krx = fdr.StockListing('krx')
'''
KOSPI 코스피 종목, KODAQ 코스닥, NASDAQ 나스닥, NYSE 뉴욕증권거래서, S&P500 ...
'''

# %%
df_krx.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        70400          1     1600
# 1  373220  KR7373220003  LG에너지솔루션  KOSPI       577000          2    -6000
# 2  000660  KR7000660001    SK하이닉스  KOSPI       109100          1     5600
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       778000          2    -1000
# 4  051910  KR7051910008      LG화학  KOSPI       702000          2   -10000
#
#    ChagesRatio    Open    High     Low    Volume         Amount  \
# 0         2.33   69800   70400   69500  14686303  1028647491850
# 1        -1.03  580000  583000  575000     71872    41631538000
# 2         5.41  107500  109700  106100   6800436   732113513700
# 3        -0.13  778000  782000  773000     13814    10746963000
# 4        -1.40  708000  716000  697000     95021    67101783000
#
#             Marcap      Stocks MarketId
# 0  420272691520000  5969782550      STK
# 1  135018000000000   234000000      STK
# ...

# %%
df_krx.shape  # 2717 주식 종목의 17가지 정보
# Out:
# (2717, 17)

# %%
df_krx.describe()
# Out:
#             Changes  ChagesRatio           Open           High            Low  \
# count   2717.000000  2717.000000    2717.000000    2717.000000    2717.000000
# mean    -112.407435    -0.478105   20853.210894   21091.692308   20538.243651
# std      925.272991     2.747316   53295.045906   53749.792117   52639.924875
# min   -22000.000000   -15.000000       0.000000       0.000000       0.000000
# 25%     -125.000000    -1.500000    2865.000000    2900.000000    2800.000000
# 50%      -30.000000    -0.590000    6780.000000    6920.000000    6650.000000
# 75%        0.000000     0.000000   16880.000000   17200.000000   16580.000000
# max    12500.000000    30.000000  778000.000000  782000.000000  773000.000000
#
#              Volume        Amount        Marcap        Stocks
# count  2.717000e+03  2.717000e+03  2.717000e+03  2.717000e+03
# mean   4.580484e+05  4.391842e+09  8.971547e+11  4.186701e+07
# std    2.499807e+06  2.847257e+10  9.083574e+12  1.343060e+08
# ...

# %%
df_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2717 entries, 0 to 2716
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         2717 non-null   object
#  1   ISU_CD       2717 non-null   object
#  2   Name         2717 non-null   object
#  3   Market       2717 non-null   object
#  4   Dept         2717 non-null   object
#  5   Close        2717 non-null   object
#  6   ChangeCode   2717 non-null   object
#  7   Changes      2717 non-null   int64
#  8   ChagesRatio  2717 non-null   float64
#  9   Open         2717 non-null   int64
#  10  High         2717 non-null   int64
#  11  Low          2717 non-null   int64
#  12  Volume       2717 non-null   int64
#  13  Amount       2717 non-null   int64
#  14  Marcap       2717 non-null   int64
#  15  Stocks       2717 non-null   int64
#  16  MarketId     2717 non-null   object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 361.0+ KB

# %%
samsung_df = fdr.DataReader('005930')

# %%
samsung_df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1999-02-10   1653   1675   1604   1634    664282       NaN
# 1999-02-11   1661   1678   1643   1644    287590  0.006120
# 1999-02-12   1682   1751   1667   1743    403600  0.060219
# 1999-02-18   1712   1721   1682   1687    440930 -0.032129
# 1999-02-19   1663   1663   1602   1653    503847 -0.020154
# ...           ...    ...    ...    ...       ...       ...
# 2023-05-22  68400  69000  68000  68500  14470308  0.001462
# 2023-05-23  68500  68700  68100  68400   8561643 -0.001460
# 2023-05-24  68100  68700  68000  68500   8192896  0.001462
# 2023-05-25  69900  70000  68700  68800  14231160  0.004380
# 2023-05-26  69800  70400  69500  70300  15035853  0.021802
#
# [6000 rows x 6 columns]

# %%
samsung_df = fdr.DataReader('005930', '2022')  # 2022년 부터

# %%
samsung_df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# ...           ...    ...    ...    ...       ...       ...
# 2023-05-22  68400  69000  68000  68500  14470308  0.001462
# 2023-05-23  68500  68700  68100  68400   8561643 -0.001460
# 2023-05-24  68100  68700  68000  68500   8192896  0.001462
# 2023-05-25  69900  70000  68700  68800  14231160  0.004380
# 2023-05-26  69800  70400  69500  70400  15052282  0.023256
#
# [346 rows x 6 columns]

# %%
samsung_df = fdr.DataReader('005930', '2021','2022') # 2021년부터 2021년 12월까지 Default 0101이 뒤에 붙음
samsung_df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170
# ...           ...    ...    ...    ...       ...       ...
# 2022-12-23  58200  58400  57700  58100   9829407 -0.016920
# 2022-12-26  58000  58100  57700  57900   6756411 -0.003442
# 2022-12-27  58000  58400  57900  58100  10667027  0.003454
# 2022-12-28  57600  57600  56400  56600  14665410 -0.025818
# 2022-12-29  56000  56200  55300  55300  11295935 -0.022968
#
# [494 rows x 6 columns]

# %%
samsung_df = fdr.DataReader('005930', '20210301','20220601') 
samsung_df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-03-02  85100  85300  83000  83600  33498180  0.013333
# 2021-03-03  83500  84000  82800  84000  19882132  0.004785
# 2021-03-04  82600  83200  82200  82400  24348331 -0.019048
# 2021-03-05  81100  82600  81100  82100  20508971 -0.003641
# 2021-03-08  82900  83000  81600  82000  17641256 -0.001218
# ...           ...    ...    ...    ...       ...       ...
# 2022-05-25  66700  67100  65900  66400  15150490 -0.001504
# 2022-05-26  66300  67200  65500  65900  15970890 -0.007530
# 2022-05-27  66700  66900  66200  66500  11405555  0.009105
# 2022-05-30  67500  67800  66900  67700  14255484  0.018045
# 2022-05-31  67500  67500  66700  67400  24365002 -0.004431
#
# [311 rows x 6 columns]

# %%
samsung_df = fdr.DataReader('005930', '2021-03-01','20220601') 
samsung_df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-03-02  85100  85300  83000  83600  33498180  0.013333
# 2021-03-03  83500  84000  82800  84000  19882132  0.004785
# 2021-03-04  82600  83200  82200  82400  24348331 -0.019048
# 2021-03-05  81100  82600  81100  82100  20508971 -0.003641
# 2021-03-08  82900  83000  81600  82000  17641256 -0.001218
# ...           ...    ...    ...    ...       ...       ...
# 2022-05-25  66700  67100  65900  66400  15150490 -0.001504
# 2022-05-26  66300  67200  65500  65900  15970890 -0.007530
# 2022-05-27  66700  66900  66200  66500  11405555  0.009105
# 2022-05-30  67500  67800  66900  67700  14255484  0.018045
# 2022-05-31  67500  67500  66700  67400  24365002 -0.004431
#
# [311 rows x 6 columns]

# %% [markdown]
# ### 상장 폐지 종목 데이터

# %%
del_stock = fdr.DataReader('003497', exchange = 'krx-delisting') # 003497 상장 폐지 -> krx에는 데이터가 없음, exchange = 'krx-delisting'
del_stock
# Out:
#           Date    Code       Name Market SecuGroup  Close  UpDown  Change  \
# 0   2001-04-13  003497  대한항공(2우B)  KOSPI        주권   6100       0       0
# 1   2001-04-12  003497  대한항공(2우B)  KOSPI        주권   6100       0       0
# 2   2001-04-11  003497  대한항공(2우B)  KOSPI        주권   6100       0       0
# 3   2001-04-10  003497  대한항공(2우B)  KOSPI        주권   6100       0       0
# 4   2001-04-09  003497  대한항공(2우B)  KOSPI        주권   6100       0       0
# ..         ...     ...        ...    ...       ...    ...     ...     ...
# 753 1998-04-30  003497  대한항공(2우B)  KOSPI        주권   1915       1       5
# 754 1998-04-29  003497  대한항공(2우B)  KOSPI        주권   1910       2     -95
# 755 1998-04-28  003497  대한항공(2우B)  KOSPI        주권   2005       1       5
# 756 1998-04-27  003497  대한항공(2우B)  KOSPI        주권   2000       1      90
# 757 1998-04-25  003497  대한항공(2우B)  KOSPI        주권      0       0       0
#
#      ChangeRate  Open  High  Lower  Volume  Amount      MarCap
# ...

# %% [markdown]
# ## 단일 종목 그래프

# %%
samsung_df_2022_ = fdr.DataReader('005930', '2022-01-03', '2022-03-31')
samsung_df_2022_
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# 2022-01-10  78100  78100  77100  78000   9947422 -0.003831
# 2022-01-11  78400  79000  78000  78900  13221123  0.011538
# 2022-01-12  79500  79600  78600  78900  11000502  0.000000
# 2022-01-13  79300  79300  77900  77900  13889401 -0.012674
# 2022-01-14  77700  78100  77100  77300  10096725 -0.007702
# 2022-01-17  77600  77800  76900  77500   8785122  0.002587
# 2022-01-18  77600  77800  76600  77000   9592788 -0.006452
# 2022-01-19  76500  76900  76100  76300  10598290 -0.009091
# 2022-01-20  76200  76700  75900  76500   9708168  0.002621
# 2022-01-21  75800  75800  74700  75600  15774888 -0.011765
# ...

# %%
# 종가
samsung_df_2022_['Close']
# Out:
# Date
# 2022-01-03    78600
# 2022-01-04    78700
# 2022-01-05    77400
# 2022-01-06    76900
# 2022-01-07    78300
# 2022-01-10    78000
# 2022-01-11    78900
# 2022-01-12    78900
# 2022-01-13    77900
# 2022-01-14    77300
# 2022-01-17    77500
# 2022-01-18    77000
# 2022-01-19    76300
# 2022-01-20    76500
# 2022-01-21    75600
# 2022-01-24    75100
# 2022-01-25    74000
# 2022-01-26    73300
# 2022-01-27    71300
# 2022-01-28    73300
# 2022-02-03    73300
# 2022-02-04    74000
# 2022-02-07    73000
# 2022-02-08    73500
# 2022-02-09    74700
# 2022-02-10    75400
# 2022-02-11    74900
# 2022-02-14    73700
# 2022-02-15    73700
# 2022-02-16    74800
# 2022-02-17    75000
# 2022-02-18    74300
# 2022-02-21    74200
# 2022-02-22    73400
# 2022-02-23    73000
# 2022-02-24    71500
# 2022-02-25    71900
# 2022-02-28    72100
# 2022-03-02    71700
# 2022-03-03    72900
# 2022-03-04    71500
# 2022-03-07    70100
# 2022-03-08    69500
# 2022-03-10    71200
# 2022-03-11    70000
# ...

# %%
samsung_df_2022_['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# 시가

samsung_df_2022_['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 환율 데이터

# %%
ex_us_kw_df = fdr.DataReader('USD/KRW', '2023')
ex_us_kw_df

# EUR/USD(유로당 달러), CNY/KRW(위엔당 원), JPY/KRW(엔당 원), USD/JPY(달러당 엔)...
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-01-02  1260.910034  1273.930054  1256.550049  1260.910034  1260.910034
# 2023-01-03  1270.099976  1278.969971  1264.390015  1270.099976  1270.099976
# 2023-01-04  1279.079956  1279.719971  1267.560059  1279.079956  1279.079956
# 2023-01-05  1271.079956  1278.229980  1265.739990  1271.079956  1271.079956
# 2023-01-06  1274.180054  1274.180054  1253.010010  1274.180054  1274.180054
# ...                 ...          ...          ...          ...          ...
# 2023-05-22  1324.209961  1324.219971  1312.430054  1324.209961  1324.209961
# 2023-05-23  1313.829956  1321.729980  1308.260010  1313.829956  1313.829956
# 2023-05-24  1319.839966  1320.300049  1314.089966  1319.839966  1319.839966
# 2023-05-25  1318.520020  1330.109985  1317.349976  1318.520020  1318.520020
# 2023-05-26  1329.400024  1330.609985  1322.709961  1323.829956  1323.829956
#
#             Volume
# Date
# 2023-01-02       0
# ...

# %%
ex_us_kw_df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ex_us_kw_df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 암호화폐 데이터

# %%
btc_krw_df = fdr.DataReader('BTC/KRW', '2023')
btc_krw_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-01  20881980.0  20983694.0  20848310.0  20976934.0  20976934.0
# 2023-01-02  20977476.0  21355044.0  20930146.0  21196110.0  21196110.0
# 2023-01-03  21196588.0  21310532.0  21286596.0  21340292.0  21340292.0
# 2023-01-04  21340738.0  21612098.0  21267144.0  21440006.0  21440006.0
# 2023-01-05  21440302.0  21411704.0  21411510.0  21458506.0  21458506.0
# ...                ...         ...         ...         ...         ...
# 2023-05-22  35937472.0  36132932.0  35393188.0  35454384.0  35454384.0
# 2023-05-23  35449176.0  35568568.0  35105516.0  35287412.0  35287412.0
# 2023-05-24  35293568.0  35985904.0  35170116.0  35943132.0  35943132.0
# 2023-05-25  35941648.0  35941648.0  34468484.0  34730844.0  34730844.0
# 2023-05-26  35252636.0  35155736.0  34992524.0  34992524.0  34992524.0
#
#                     Volume
# Date
# 2023-01-01  11664205615481
# 2023-01-02  15365444804389
# ...

# %%
btc_krw_df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
btc_krw_df = fdr.DataReader('BTC/KRW', '20141001')
btc_krw_df

#BTC/KRW(비트코인당 원), ETR/KRW(이더리움당 원), XRP/KRW(리플당 원)
#BTC/USD(비트코인당 달러0)...
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-10-01  4.085612e+05  4.162316e+05  4.046549e+05  4.076677e+05
# 2014-10-02  4.080641e+05  4.084726e+05  3.957330e+05  3.979889e+05
# 2014-10-03  3.981046e+05  4.007722e+05  3.797242e+05  3.814782e+05
# 2014-10-04  3.818814e+05  3.867572e+05  3.457976e+05  3.489597e+05
# 2014-10-05  3.490128e+05  3.626850e+05  3.069720e+05  3.400932e+05
# ...                  ...           ...           ...           ...
# 2023-05-22  3.593747e+07  3.613293e+07  3.539319e+07  3.545438e+07
# 2023-05-23  3.544918e+07  3.556857e+07  3.510552e+07  3.528741e+07
# 2023-05-24  3.529357e+07  3.598590e+07  3.517012e+07  3.594313e+07
# 2023-05-25  3.594165e+07  3.594165e+07  3.446848e+07  3.473084e+07
# 2023-05-26  3.525264e+07  3.515574e+07  3.499750e+07  3.499750e+07
#
#                Adj Close          Volume
# Date
# 2014-10-01  4.076677e+05     27873983380
# 2014-10-02  3.979889e+05     23108317470
# ...

# %% [markdown]
# ## 파일 데이터

# %% [markdown]
# ### 한글(.hwp) 파일 크롤링
#
# - ole 라이브러리

# %% [markdown]
# ole 라이브러리 설치

# %%
# !pip install ole-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import pandas as pd
import ole

# 경로 설정
dir_path = 'data_hwp/'

# 파일 이름 설정
hwp_name = '예제.hwp'

# 경로 + 파일
hwp_path = os.path.join(dir_path, hwp_name)

# 불러오기
f = ole.open(hwp_path)

content = f.get_stream('PrvText').read().decode('utf-16le')
print(content)

# %% [markdown]
# ```
# [서식. 참가신청서]
# <교육 참가신청서>
# <교 육 명><인공지능을 활용한 업무자동화 교육>
# <교육일시><2019년 2월 15일(금) ~ 17일(일), 2박 3일>
# <참가자 정보><성    명><홍길동><소    속><세종대학교><연 락 처><010.0000.0000>
# <E-mail><example_jeju_gdg><주    소><서울특별시 중랑구><연 령 대>
# <□ 10대       □ 20대      □ 30대      □ 40대이상>
# <신청내용><관심분야 (중복선택가능)>
# <□ HTML&CSS  □ Javascript  □ Python  □ 서비스기획·런칭  □ 기타 (          )>
# <지원동기 (자유롭게 서술)>
# <평소에 파이썬에 관심이 많았습니다.  업무자동화를 저의 업무에 적용하고 싶었는데.
# 마침 좋은 기회가 있어서 지원하게 되었습니다.  이런 기회를 주셔서 감사합니다. >
# <기술역량  및 경험 (자유롭게 서술)><파이썬은 1년 했고, 다른 쪽 개발 경험은 없습니다.  파이썬을 배우고 싶습니다. >
# <상기와 같이 참가를 신청합니다. 2019년   1월   일 <신 청 자 :><홍길동><(서명 또는 날인) >>
# ```

# %%
# excel 파일로 변환하기

columns = ['Name', 'Company', 'Phone', 'e-mail', 'why', 'experience']

df = pd.DataFrame(columns=columns)


# 읽어온 값을 hwp 분리해서 딕셔너리
word_list = content.split('><')
target_list = ['성    명', '소    속', '연 락 처', 'E-mail', '주    소', '연 령 대']

info_dict = {} # 데이터 추출 후 저장할 빈 딕셔너리
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-fe3d4f8226b3> in <cell line: 5>()
#       3 columns = ['Name', 'Company', 'Phone', 'e-mail', 'why', 'experience']
#       4
# ----> 5 df = pd.DataFrame(columns=columns)
#       6
#       7
#
# NameError: name 'pd' is not defined

# %%
for n, target in enumerate(target_list):
  info = word_list[word_list.index(target) + 1]
  info_dict[column[n]] = info

df = pd.DataFrame(data=info_dict, index=[0], columns=columns)
df

# %%
df.to_excel('예제.xlsx')

# %% [markdown]
# ## PDF 데이터 크롤링

# %%
# 모듈 임포트
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-117-2762687e4b09> in <cell line: 2>()
#       1 # 모듈 임포트
# ----> 2 from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
#       3 from pdfminer.converter import TextConverter
#       4 from pdfminer.layout import LAParams
#       5 from pdfminer.pdfpage import PDFPage
#
# ModuleNotFoundError: No module named 'pdfminer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def pdf2txt(pdf_file):
    rsrcmgr = PDFResourceManager()
   
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(pdf_file, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos = set()
    
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,
                                 caching=caching, check_extractable=True):
        interpreter.process_page(page)
    
    text = retstr.getvalue()
    
    fp.close()
    device.close()
    retstr.close()
    return text

# %%
# pdf 파일 불러오기

import os
os.chdir('C:\workspace')
os.listdir('sample/')
pdf_path='sample/「인공지능 업무자동화교육」 참가신청서.pdf'

# %%
text = pdf2txt(pdf_path)
text

# %% [markdown]
# # 연습문제
#
# - Requests, BeautifulSoup을 이용해서 데이터를 가져오기
# - http://www.paullab.co.kr/stock.html 데이터중 main 클래스틔 2번째 값을 가져오기

# %%
import requests
from bs4 import BeautifulSoup

html = requests.get('http://www.paullab.co.kr/stock.html')
text = html.text
soup = BeautifulSoup(text, 'html.parser')

main = soup.select('.main')[1]
main
# Out:
# <div class="wrap main">
# <div class="cat-img">
# <img alt="(주)캣네가게 주가" src="cats_stock.png"/>
# </div>
# <div class="tables">
# <table class="border-style" summary="시가총액 정보">
# <tr>
# <th class="strong" scope="row">시가총액</th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td class="strong"><em id="_market_sum">349조 2,323</em>억원</td>
# </tr>
# <tr>
# <th scope="row">
# <a class="link_site" href="#">시가총액순위<i class="fas fa-caret-right"></i></a>
# </th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td>위니브월드 <em id="_market_sum">1</em>위</td>
# </tr>
# <tr>
# <th scope="row">상장주식수</th>
# <!-- 공백은 의도적으로 넣은 것입니다. -->
# <td><em id="_market_sum">5,969,782,550</em></td>
# </tr>
# </table>
# <table class="border-style" summary="업종상세 정보">
# <tr>
# <th class="strong" scope="row">현재가</th>
# <td class="strong"><em id="_market_sum">349조 2,323</em>억원</td>
# </tr>
# <tr>
# <th scope="row">52주 최고 <span class="bar">l</span> 최저</th>
# <td>
# <em>62,800</em>
# <span class="bar">l</span>
# <em>42,300</em>
# </td>
# </tr>
# <tr>
# ...

# %% [markdown]
# 제주코딩베이스캠프 연구원의 일별 시세 테이블을 가져와주세요.

# %%
import requests
from bs4 import BeautifulSoup

html = requests.get('http://www.paullab.co.kr/stock.html')
text = html.text
soup = BeautifulSoup(text, 'html.parser')

main = soup.select('body > div:nth-child(3) > table')
main
# Out:
# [<table class="table table-hover">
#  <tbody>
#  <tr>
#  <th scope="col">날짜</th>
#  <th scope="col">종가</th>
#  <th scope="col">전일비</th>
#  <th scope="col">시가</th>
#  <th scope="col">고가</th>
#  <th scope="col">저가</th>
#  <th scope="col">거래량</th>
#  </tr>
#  <tr>
#  <td align="center "><span class="date">2019.10.23</span></td>
#  <td class="num"><span>6,650</span></td>
#  <td class="num">
#  <img alt="상승 " height="6 " src="ico_up.gif " style="margin-right:4px; " width="7 "/><span>
#                              20
#                          </span>
#  </td>
#  <td class="num"><span>6,590</span></td>
#  <td class="num"><span>6,830</span></td>
#  <td class="num"><span>6,580</span></td>
#  <td class="num"><span>398,421</span></td>
#  </tr>
#  <tr>
#  <td align="center"><span class="date">2019.10.22</span></td>
#  <td class="num"><span>6,630</span></td>
#  <td class="num">
#  <img alt="하락" height="6" src="ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# ...

# %% [markdown]
# (주) 캣네생선의 왼쪽 이미지를 불러온 뒤, 위 아래 반전시켜주세요.
# http://paullab.synology.me/cats_stock.png

# %%
# !pip install Pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-e31b55a19051> in <cell line: 1>()
# ----> 1 os = chdir('/content/')
#
# NameError: name 'chdir' is not defined

# %%
from PIL import Image
import matplotlib.pyplot as plt

cat = Image.open('cats_stock.png')

import numpy as np
pixel = np.array(cat)

plt.imshow(pixel[::-1, ::-1])

# %% [markdown]
# - sk 하이닉스의 2020년도 데이터를 출력하고 그 시가 데이터를 그래프로 나타내시오

# %%
import FinanceDataReader as fdr

df_sk = fdr.DataReader('000660', '2020-01-01', '2020-12-31')  # 2022년 부터

df_sk['Close'].plot()
# Out:
# <Axes: xlabel='Date'>
